# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import matplotlib.cm as cm
import pandas as pd

# %%
#parse the foodweb data

file_path = "Foodweb/data.xls"


#read the data
data = pd.read_excel(file_path)
#There are 2 different data sets in the file (ID,TSN,Name,Phylum) then a gap and it repeats again for the second data set (ID,TSN,Name,Phylum)
#separate the data into 2 dataframes
intertidal = data.iloc[:, :4]
#keep data1 until the first nan value row
intertidal = intertidal[intertidal.notna().all(axis=1)]
nearshore = data.iloc[:, 5:]






print(nearshore)
# Out:
#     Sanak Nearshore Marine Food Web Unnamed: 6         Unnamed: 7  \
# 0                                ID        TSN               Name
# 1                                 1      10031        Gymnodinium
# 2                                 2      10212         Peridinium
# 3                                 3      10340    Protoperidinium
# 4                                 4      10359          Gonyaulax
# ..                              ...        ...                ...
# 509                             509     179725       Corvus corax
# 510                             510     554029  Aethia psittacula
# 511                             511     554127   Anthus rubescens
# 512                             512     686683    Bubo scandiacus
# 513                             513      78536  Cinclus mexicanus
#
#           Unnamed: 8
# 0             Phylum
# 1    Pyrrophycophyta
# 2    Pyrrophycophyta
# 3    Pyrrophycophyta
# 4    Pyrrophycophyta
# ..               ...
# 509         Chordata
# 510         Chordata
# 511         Chordata
# 512         Chordata
# 513         Chordata
#
# [514 rows x 4 columns]

# %%
# This cell was redundant - removed

# %%
#check the Trophic Links sheet

trophic_links = pd.read_excel(file_path, sheet_name="Trophic Links")

print(trophic_links)
# Out:
#      Sanak Intertidal Food Web Unnamed: 1  Unnamed: 2  \
# 0                     Consumer   Resource         NaN
# 1                            9          9         NaN
# 2                            9         64         NaN
# 3                            9         87         NaN
# 4                            9        150         NaN
# ...                        ...        ...         ...
# 6770                       NaN        NaN         NaN
# 6771                       NaN        NaN         NaN
# 6772                       NaN        NaN         NaN
# 6773                       NaN        NaN         NaN
# 6774                       NaN        NaN         NaN
#
#      Sanak Nearshore Marine Food Web Unnamed: 4
# 0                           Consumer   Resource
# 1                                  1        200
# 2                                  1        241
# 3                                  1        244
# 4                                  2          1
# ...                              ...        ...
# 6770                             512        504
# 6771                             512        506
# 6772                             512        507
# 6773                             512        508
# 6774                             513        217
#
# [6775 rows x 5 columns]

# %%
#separate the data into 2 dataframes (ID,ID) gap (ID,ID)
intertidal_links = trophic_links.iloc[:, :2]
#also remove the rows with nan value
intertidal_links = intertidal_links[intertidal_links.notna().all(axis=1)]
nearshore_links = trophic_links.iloc[:, 3:5]  # Fix: Only take 2 columns, not all remaining
#also remove the rows with nan value for nearshore links
nearshore_links = nearshore_links[nearshore_links.notna().all(axis=1)]

#print the dataframes
print(intertidal_links)
# Out:
#      Sanak Intertidal Food Web Unnamed: 1
# 0                     Consumer   Resource
# 1                            9          9
# 2                            9         64
# 3                            9         87
# 4                            9        150
# ...                        ...        ...
# 1800                       234        226
# 1801                       234        228
# 1802                       234        229
# 1803                       234        230
# 1804                       235         73
#
# [1805 rows x 2 columns]

# %%
print(nearshore_links)
# Out:
#      Sanak Nearshore Marine Food Web Unnamed: 4
# 0                           Consumer   Resource
# 1                                  1        200
# 2                                  1        241
# 3                                  1        244
# 4                                  2          1
# ...                              ...        ...
# 6770                             512        504
# 6771                             512        506
# 6772                             512        507
# 6773                             512        508
# 6774                             513        217
#
# [6775 rows x 2 columns]

# %%
#the first row is the title row, so we need to use it as the header but not as a row

intertidal.columns = intertidal.iloc[0]


intertidal = intertidal.iloc[1:]

intertidal.head()
# Out:
# 0 ID    TSN                  Name      Phylum
# 1  1  10824  Pilayella littoralis  Phaeophyta
# 2  2  11217             Laminaria  Phaeophyta
# 3  3  11246                Agarum  Phaeophyta
# 4  4  11250      Costaria costata  Phaeophyta
# 5  5  11255    Saccharina sessile  Phaeophyta

# %%
#same for nearshore
nearshore.columns=nearshore.iloc[0]
nearshore=nearshore.iloc[1:]

nearshore.head()
# Out:
# 0 ID    TSN             Name           Phylum
# 1  1  10031      Gymnodinium  Pyrrophycophyta
# 2  2  10212       Peridinium  Pyrrophycophyta
# 3  3  10340  Protoperidinium  Pyrrophycophyta
# 4  4  10359        Gonyaulax  Pyrrophycophyta
# 5  5  10397         Ceratium  Pyrrophycophyta

# %%
#same for intertidal links
intertidal_links.columns = intertidal_links.iloc[0]
intertidal_links = intertidal_links.iloc[1:]


intertidal_links.head()
# Out:
# 0 Consumer Resource
# 1        9        9
# 2        9       64
# 3        9       87
# 4        9      150
# 5        9      168

# %%
#same for nearshore links
nearshore_links.columns = nearshore_links.iloc[0]
nearshore_links = nearshore_links.iloc[1:]
nearshore_links.head()
# Out:
# 0 Consumer Resource
# 1        1      200
# 2        1      241
# 3        1      244
# 4        2        1
# 5        2        2

# %%
#now we have the dataframe of the nodes and the links
#first lets check if all the nodes of the smallest network are present in the other network
#lets check the intertidal network
#get the TSNS of the intertidal network(the second column)
intertidal_TSNS = intertidal.iloc[:, 1]
#get the TSNS of the nearshore network(the second column)
nearshore_TSNS = nearshore.iloc[:, 1]
#print the length of the nodes
print(len(intertidal_TSNS))
print(len(nearshore_TSNS))
# Out:
# 233
# 513

# %%
#since intetidal has less we will check if all the nodes of the intertidal network are present in the nearshore network
#summarize the results
print(intertidal_TSNS.isin(nearshore_TSNS).value_counts())
#almost all of them are present but not all so we cannot disregard it 
#however we can merge the two datasets and add two columns to indicate if the species is intertidal and/or nearshore

#print the intertidals that are not in the nearshore
print(intertidal_TSNS[~intertidal_TSNS.isin(nearshore_TSNS)])
# Out:
# TSN
# True     226
# False      7
# Name: count, dtype: int64
# 64      2286
# 66     43781
# 69     46211
# 112    73727
# 151     9512
# 153    95500
# 162     9874
# Name: TSN, dtype: object

# %%
#first lets merge the two datasets but without the ID column
#select only TSN, Name, and Phylum columns for merging
intertidal_clean = intertidal[["TSN", "Name", "Phylum"]].copy()
nearshore_clean = nearshore[["TSN", "Name", "Phylum"]].copy()

merged_data = pd.merge(intertidal_clean, nearshore_clean, on="TSN", how="outer", suffixes=('_intertidal', '_nearshore'))

#combine Name and Phylum columns - use intertidal values first, then nearshore if intertidal is NaN
merged_data["Name"] = merged_data["Name_intertidal"].fillna(merged_data["Name_nearshore"])
merged_data["Phylum"] = merged_data["Phylum_intertidal"].fillna(merged_data["Phylum_nearshore"])

#drop the separate columns
merged_data = merged_data.drop(["Name_intertidal", "Name_nearshore", "Phylum_intertidal", "Phylum_nearshore"], axis=1)

#add the two columns
merged_data["Intertidal"] = merged_data["TSN"].isin(intertidal_TSNS)
merged_data["Nearshore"] = merged_data["TSN"].isin(nearshore_TSNS)

print(merged_data)
# Out:
# 0       TSN                      Name           Phylum  Intertidal  Nearshore
# 0       601              Cyanophycota     Cyanophycota        True       True
# 1      1447               Chrysophyta      Chrysophyta        True       True
# 2      2135          Prymnesiophyceae       Haptophyta        True       True
# 3      2286           Bacillariophyta  Bacillariophyta        True      False
# 4      2546             Coscinodiscus  Bacillariophyta       False       True
# ..      ...                       ...              ...         ...        ...
# 515  san419            Phyllobothrium  Platyhelminthes       False       True
# 516  san420     Nybelinia surmenicola  Platyhelminthes       False       True
# 517  san455             Thalassomyces         Protozoa       False       True
# 518  san788  Hysterothylacium aduncum           Nemata       False       True
# 519  san934           Pseudoterranova           Nemata       False       True
#
# [520 rows x 5 columns]

# %%
#now we also need to merge the links but before we do that we need to change the ID's to TSN's
#starting from intertidal dataset we create a dictionary of the ID and TSN
intertidal_ID_TSN = dict(zip(intertidal["ID"], intertidal["TSN"]))
#now we can use this dictionary to map the ID's to TSN's in the intertidal_links dataframe
intertidal_links_TSN = intertidal_links.copy()
intertidal_links_TSN["Consumer"] = intertidal_links_TSN["Consumer"].map(intertidal_ID_TSN)
intertidal_links_TSN["Resource"] = intertidal_links_TSN["Resource"].map(intertidal_ID_TSN)

# Remove rows where mapping failed (NaN values)
intertidal_links_TSN = intertidal_links_TSN.dropna()
print(intertidal_links_TSN)

#now we do the same for the nearshore dataset
nearshore_ID_TSN = dict(zip(nearshore["ID"], nearshore["TSN"]))
#now we can use this dictionary to map the ID's to TSN's in the nearshore_links dataframe
nearshore_links_TSN = nearshore_links.copy()
nearshore_links_TSN["Consumer"] = nearshore_links_TSN["Consumer"].map(nearshore_ID_TSN)
nearshore_links_TSN["Resource"] = nearshore_links_TSN["Resource"].map(nearshore_ID_TSN)

# Remove rows where mapping failed (NaN values)
nearshore_links_TSN = nearshore_links_TSN.dropna()
print(nearshore_links_TSN)
# Out:
# 0    Consumer Resource
# 1      113265   113265
# 2      113265     2286
# 3      113265      601
# 4      113265    93295
# 6        1447   202421
# ...       ...      ...
# 1800   686683   177935
# 1801   686683   179492
# 1802   686683   179526
# 1803   686683   179531
# 1804    78536    48739
#
# [1689 rows x 2 columns]
# 0    Consumer Resource
# 1       10031     2135
# 2       10031   590745
# 3       10031      601
# 4       10212    10031
# 5       10212    10212
# ...       ...      ...
# 6770   686683   177935
# 6771   686683   179492
# 6772   686683   179526
# 6773   686683   179531
# 6774    78536    48739
#
# [6774 rows x 2 columns]

# %%
# We want to create a merged links dataframe with one row per unique (Consumer, Resource) pair,
# and two columns: 'Intertidal' and 'Nearshore', indicating presence (True/False) in each network.

# First, get sets of (Consumer, Resource) tuples for each network
intertidal_links_set = set(tuple(x) for x in intertidal_links_TSN[["Consumer", "Resource"]].values)
nearshore_links_set = set(tuple(x) for x in nearshore_links_TSN[["Consumer", "Resource"]].values)

# Get all unique links
all_links = intertidal_links_set.union(nearshore_links_set)

# Build the merged DataFrame
merged_links = pd.DataFrame(list(all_links), columns=["Consumer", "Resource"])
merged_links["Intertidal"] = merged_links.apply(lambda row: (row["Consumer"], row["Resource"]) in intertidal_links_set, axis=1)
merged_links["Nearshore"] = merged_links.apply(lambda row: (row["Consumer"], row["Resource"]) in nearshore_links_set, axis=1)

print(merged_links)
# Out:
#      Consumer Resource  Intertidal  Nearshore
# 0      157215   157215       False       True
# 1       73293    89609        True       True
# 2      157152   202421        True       True
# 3      165427    97106       False       True
# 4      172932    97774       False       True
# ...       ...      ...         ...        ...
# 6912   177013   667083       False       True
# 6913   164722    82415       False       True
# 6914    85524   158650       False       True
# 6915   180480   167123       False       True
# 6916    65870   san266       False       True
#
# [6917 rows x 4 columns]

# %%
#now create an nx graph from the merged links dataframe but also use the metadata from the merged_data dataframe

# Create a directed graph
G = nx.DiGraph()

# Add nodes for all unique TSNs in merged_links, with metadata from merged_data if available
all_TSNs = set(merged_links["Consumer"]).union(set(merged_links["Resource"]))

# merged_data should have TSN as a column; if not, adjust accordingly
for tsn in all_TSNs:
    # Try to get metadata for this TSN from merged_data
    if "TSN" in merged_data.columns:
        meta = merged_data[merged_data["TSN"] == tsn]
        if not meta.empty:
            node_attrs = meta.iloc[0].to_dict()
        else:
            node_attrs = {}
    else:
        node_attrs = {}
    G.add_node(tsn, **node_attrs)

# Add edges with attributes for Intertidal and Nearshore presence
for _, row in merged_links.iterrows():
    consumer = row["Consumer"]
    resource = row["Resource"]
    intertidal = row["Intertidal"]
    nearshore = row["Nearshore"]
    G.add_edge(consumer, resource, Intertidal=intertidal, Nearshore=nearshore)

# %%
#using the graph filter only the intertidal links
#filter edges directly from G based on edge attributes
intertidal_edges = [(u, v) for u, v, d in G.edges(data=True) if d.get("Intertidal") == True]
#create subgraph
intertidal_G = G.edge_subgraph(intertidal_edges)

#visualize the intertidal graph with better layout and styling
plt.figure(figsize=(15, 10))

# Use spring layout for better positioning
pos = nx.spring_layout(intertidal_G, k=1, iterations=50)

# Draw nodes with different colors based on phylum
phyla = [intertidal_G.nodes[node].get('Phylum', 'Unknown') for node in intertidal_G.nodes()]
unique_phyla = list(set(phyla))
colors = plt.cm.Set3(np.linspace(0, 1, len(unique_phyla)))
phylum_colors = dict(zip(unique_phyla, colors))
node_colors = [phylum_colors.get(intertidal_G.nodes[node].get('Phylum', 'Unknown'), 'gray') for node in intertidal_G.nodes()]

# Draw the graph
nx.draw(intertidal_G, pos, 
        node_color=node_colors,
        node_size=50,
        with_labels=False,  # Remove labels for cleaner look
        edge_color='lightgray',
        alpha=0.7,
        arrows=True,
        arrowsize=10)

# Add legend for phyla
legend_elements = [plt.scatter([], [], c=color, s=100, label=phylum) for phylum, color in phylum_colors.items()]
plt.legend(handles=legend_elements, loc='upper left', bbox_to_anchor=(1, 1))

plt.title(f'Intertidal Food Web Network ({intertidal_G.number_of_nodes()} nodes, {intertidal_G.number_of_edges()} edges)')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\thano\AppData\Local\Temp\ipykernel_3632\2137606884.py:31: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   legend_elements = [plt.scatter([], [], c=color, s=100, label=phylum) for phylum, color in phylum_colors.items()]
# C:\Users\thano\AppData\Local\Temp\ipykernel_3632\2137606884.py:35: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
# Create nearshore subgraph
nearshore_edges = [(u, v) for u, v, d in G.edges(data=True) if d.get("Nearshore") == True]
nearshore_G = G.edge_subgraph(nearshore_edges)

print(f"Nearshore graph created: {nearshore_G.number_of_nodes()} nodes, {nearshore_G.number_of_edges()} edges")
# Out:
# Nearshore graph created: 513 nodes, 6774 edges

# %%
#iterate through edges 
both=0
one=0
for edge in G.edges(data=True):
    #check if both nodes are intertidal and nearshore

    if G.nodes[edge[0]]["Intertidal"] and G.nodes[edge[0]]["Nearshore"] and G.nodes[edge[1]]["Intertidal"] and G.nodes[edge[1]]["Nearshore"]:
        #if the edge is both intertidal and nearshore add 1 to both
        if edge[2]["Intertidal"] and edge[2]["Nearshore"]:
            both+=1
            print(edge)
            print(G.nodes[edge[0]])
            print(G.nodes[edge[1]])
        else:
            one+=1
print(both)
print(one)
# Out:
# (69662, 12322, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69662, 'Name': 'Acmaea mitra', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 12322, 'Name': 'Corallina', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69662, 'san262', {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69662, 'Name': 'Acmaea mitra', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 'san262', 'Name': 'Crustose coralline algae complex', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69662, 11255, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69662, 'Name': 'Acmaea mitra', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11255, 'Name': 'Saccharina sessile', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69662, 13080, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69662, 'Name': 'Acmaea mitra', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 13080, 'Name': 'Microcladia', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69662, 11289, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69662, 'Name': 'Acmaea mitra', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11289, 'Name': 'Alaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (176177, 175062, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176177, 'Name': 'Grus canadensis', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 175062, 'Name': 'Anas', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (57443, 57443, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57443, 'Name': 'Lineidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 57443, 'Name': 'Lineidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# (57443, 57493, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57443, 'Name': 'Lineidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# (57443, 64397, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57443, 'Name': 'Lineidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 64397, 'Name': 'Polynoidae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# (57443, 65870, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57443, 'Name': 'Lineidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# (92283, 11334, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 92283, 'Name': 'Sphaeromatidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11334, 'Name': 'Fucus', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (92283, 6501, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 92283, 'Name': 'Sphaeromatidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6501, 'Name': 'Ulvaceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (92283, 6746, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 92283, 'Name': 'Sphaeromatidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6746, 'Name': 'Cladophoraceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (92283, 11365, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 92283, 'Name': 'Sphaeromatidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11365, 'Name': 'Cystoseira', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (92283, 13440, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 92283, 'Name': 'Sphaeromatidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 13440, 'Name': 'Polysiphonia', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (98435, 11277, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11277, 'Name': 'Nereocystis luetkeana', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (98435, 11334, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11334, 'Name': 'Fucus', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (98435, 11217, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11217, 'Name': 'Laminaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (98435, 39074, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 39074, 'Name': 'Zostera marina', 'Phylum': 'Magnoliophyta', 'Intertidal': True, 'Nearshore': True}
# (98435, 155471, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 155471, 'Name': 'Gymnolaemata', 'Phylum': 'Ectoprocta', 'Intertidal': True, 'Nearshore': True}
# (98435, 79452, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79452, 'Name': 'Mytilus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (98435, 11365, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11365, 'Name': 'Cystoseira', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (98435, 48739, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 48739, 'Name': 'Hydrozoa', 'Phylum': 'Cnidaria', 'Intertidal': True, 'Nearshore': True}
# (98435, 11250, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11250, 'Name': 'Costaria costata', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (98435, 13583, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 13583, 'Name': 'Odonthalia', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (98435, 92564, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 92564, 'Name': 'Idoteidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (98435, 11289, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11289, 'Name': 'Alaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (98449, 44030, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 98449, 'Name': 'Scyra', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 44030, 'Name': 'Foraminiferida', 'Phylum': 'Protozoa', 'Intertidal': True, 'Nearshore': True}
# (57493, 64397, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 64397, 'Name': 'Polynoidae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# (57493, 567816, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 567816, 'Name': 'Lottia digitalis', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (57493, 65870, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# (57493, 89609, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 89609, 'Name': 'Balanus glandula', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (57493, 67899, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 67899, 'Name': 'Terebellidae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# (57493, 66335, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 66335, 'Name': 'Lumbrineridae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# (57493, 73294, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73294, 'Name': 'Nucella lamellosa', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (57493, 89592, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 89592, 'Name': 'Chthamalus dalli', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (57493, 89688, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 89688, 'Name': 'Semibalanus cariosus', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (57493, 567823, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57493, 'Name': 'Emplectonematidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 567823, 'Name': 'Lottia pelta', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (69794, 'san14', {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 'san14', 'Name': 'Mazzaella', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 6746, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6746, 'Name': 'Cladophoraceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11365, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11365, 'Name': 'Cystoseira', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11246, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11246, 'Name': 'Agarum', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 'san338', {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 'san338', 'Name': 'Red crust complex', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11424, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11424, 'Name': 'Colpomenia', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 13080, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 13080, 'Name': 'Microcladia', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11217, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11217, 'Name': 'Laminaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11289, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11289, 'Name': 'Alaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 12322, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 12322, 'Name': 'Corallina', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 'san262', {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 'san262', 'Name': 'Crustose coralline algae complex', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11277, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11277, 'Name': 'Nereocystis luetkeana', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 'san252', {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 'san252', 'Name': 'Phaeophyta Crust', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11334, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11334, 'Name': 'Fucus', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11255, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11255, 'Name': 'Saccharina sessile', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 6895, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6895, 'Name': 'Codiaceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 'san12', {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 'san12', 'Name': 'Mastocarpus', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 11250, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11250, 'Name': 'Costaria costata', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (69794, 6501, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6501, 'Name': 'Ulvaceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (557227, 73296, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73296, 'Name': 'Nucella lima', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 79452, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79452, 'Name': 'Mytilus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 72600, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 72600, 'Name': 'Trichotropis cancellata', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 89688, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 89688, 'Name': 'Semibalanus cariosus', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (557227, 78897, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 78897, 'Name': 'Tonicella', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 98435, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (557227, 557227, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 98663, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98663, 'Name': 'Telmessus cheiragonus', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (557227, 79791, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79791, 'Name': 'Pododesmus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 157969, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (557227, 81033, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81033, 'Name': 'Macoma', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 98671, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98671, 'Name': 'Cancer', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (557227, 81464, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81464, 'Name': 'Protothaca staminea', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 81446, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81446, 'Name': 'Saxidomus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 70395, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 70395, 'Name': 'Littorina', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (557227, 72878, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 72878, 'Name': 'Naticidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (57522, 70395, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57522, 'Name': 'Amphiporidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 70395, 'Name': 'Littorina', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (57522, 92564, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57522, 'Name': 'Amphiporidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 92564, 'Name': 'Idoteidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (57522, 93295, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57522, 'Name': 'Amphiporidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 93295, 'Name': 'Gammaridea', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (57522, 95375, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 57522, 'Name': 'Amphiporidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 95375, 'Name': 'Caprellidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (84195, 601, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 84195, 'Name': 'Ostracoda', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 601, 'Name': 'Cyanophycota', 'Phylum': 'Cyanophycota', 'Intertidal': True, 'Nearshore': True}
# (84195, 202421, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 84195, 'Name': 'Ostracoda', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 202421, 'Name': 'Bacteria', 'Phylum': 'Bacteria', 'Intertidal': True, 'Nearshore': True}
# (162030, 97774, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 162030, 'Name': 'Hypomesus pretiosus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 97774, 'Name': 'Paguridae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (162030, 171672, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 162030, 'Name': 'Hypomesus pretiosus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 171672, 'Name': 'Ammodytes hexapterus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (162030, 98671, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 162030, 'Name': 'Hypomesus pretiosus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98671, 'Name': 'Cancer', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (162030, 93295, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 162030, 'Name': 'Hypomesus pretiosus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 93295, 'Name': 'Gammaridea', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (162030, 86329, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 162030, 'Name': 'Hypomesus pretiosus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 86329, 'Name': 'Harpacticidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (157969, 48739, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 48739, 'Name': 'Hydrozoa', 'Phylum': 'Cnidaria', 'Intertidal': True, 'Nearshore': True}
# (157969, 6501, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6501, 'Name': 'Ulvaceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 98435, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (157969, 73294, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73294, 'Name': 'Nucella lamellosa', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (157969, 155471, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 155471, 'Name': 'Gymnolaemata', 'Phylum': 'Ectoprocta', 'Intertidal': True, 'Nearshore': True}
# (157969, 157325, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157325, 'Name': 'Ophiuroidea', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (157969, 89687, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 89687, 'Name': 'Semibalanus balanoides', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (157969, 159300, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 159300, 'Name': 'Styela', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (157969, 157076, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157076, 'Name': 'Solaster endeca', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (157969, 10824, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 10824, 'Name': 'Pilayella littoralis', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 70370, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 70370, 'Name': 'Lacuna', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (157969, 11255, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11255, 'Name': 'Saccharina sessile', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 12841, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 12841, 'Name': 'Palmaria', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 1447, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 1447, 'Name': 'Chrysophyta', 'Phylum': 'Chrysophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 11246, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11246, 'Name': 'Agarum', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 'san338', {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 'san338', 'Name': 'Red crust complex', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 11314, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11314, 'Name': 'Desmarestia', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 11250, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11250, 'Name': 'Costaria costata', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 11540, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11540, 'Name': 'Porphyra', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 73017, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73017, 'Name': 'Fusitriton', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (157969, 11289, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11289, 'Name': 'Alaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 157969, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (157969, 6720, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6720, 'Name': 'Acrosiphoniaceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 78979, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 78979, 'Name': 'Katharina tunicata', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (157969, 12322, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 12322, 'Name': 'Corallina', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 'san262', {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 'san262', 'Name': 'Crustose coralline algae complex', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 11277, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11277, 'Name': 'Nereocystis luetkeana', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 11334, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11334, 'Name': 'Fucus', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 6895, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6895, 'Name': 'Codiaceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (157969, 11217, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11217, 'Name': 'Laminaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (67899, 6501, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 67899, 'Name': 'Terebellidae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6501, 'Name': 'Ulvaceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (67899, 202421, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 67899, 'Name': 'Terebellidae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 202421, 'Name': 'Bacteria', 'Phylum': 'Bacteria', 'Intertidal': True, 'Nearshore': True}
# (180547, 154883, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 154883, 'Name': 'Phascolosomatidae', 'Phylum': 'Sipuncula', 'Intertidal': True, 'Nearshore': True}
# (180547, 157274, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157274, 'Name': 'Pycnopodia helianthoides', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (180547, 79032, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79032, 'Name': 'Cryptochiton stelleri', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 78979, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 78979, 'Name': 'Katharina tunicata', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 80954, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 80954, 'Name': 'Tresus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 158191, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 158191, 'Name': 'Cucumaria', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (180547, 97774, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 97774, 'Name': 'Paguridae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180547, 80982, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 80982, 'Name': 'Mactromeris', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 566908, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 566908, 'Name': 'Pharidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 81910, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81910, 'Name': 'Entodesma', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 98435, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98435, 'Name': 'Pugettia', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180547, 73294, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73294, 'Name': 'Nucella lamellosa', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 174468, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 174468, 'Name': 'Gavia', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180547, 175062, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 175062, 'Name': 'Anas', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180547, 557227, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 79452, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79452, 'Name': 'Mytilus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 98663, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98663, 'Name': 'Telmessus cheiragonus', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180547, 171672, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 171672, 'Name': 'Ammodytes hexapterus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180547, 80866, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 80866, 'Name': 'Clinocardium', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 79500, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79500, 'Name': 'Modiolus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 81033, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81033, 'Name': 'Macoma', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 98671, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98671, 'Name': 'Cancer', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180547, 81464, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81464, 'Name': 'Protothaca staminea', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 81446, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81446, 'Name': 'Saxidomus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 175170, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 175170, 'Name': 'Melanitta perspicillata', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180547, 157224, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157224, 'Name': 'Evasterias troschelii', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (180547, 81760, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81760, 'Name': 'Hiatellidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 97106, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 97106, 'Name': 'Crangonidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180547, 72878, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 72878, 'Name': 'Naticidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 79791, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79791, 'Name': 'Pododesmus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180547, 157969, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (180547, 69794, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (65870, 48739, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 48739, 'Name': 'Hydrozoa', 'Phylum': 'Cnidaria', 'Intertidal': True, 'Nearshore': True}
# (65870, 44030, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 44030, 'Name': 'Foraminiferida', 'Phylum': 'Protozoa', 'Intertidal': True, 'Nearshore': True}
# (65870, 6501, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 6501, 'Name': 'Ulvaceae', 'Phylum': 'Chlorophyta', 'Intertidal': True, 'Nearshore': True}
# (65870, 93295, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 93295, 'Name': 'Gammaridea', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (65870, 92426, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 92426, 'Name': 'Limnoria', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (65870, 13583, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 13583, 'Name': 'Odonthalia', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (65870, 11334, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11334, 'Name': 'Fucus', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (65870, 11217, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11217, 'Name': 'Laminaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (65870, 39074, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 39074, 'Name': 'Zostera marina', 'Phylum': 'Magnoliophyta', 'Intertidal': True, 'Nearshore': True}
# (65870, 65870, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# (65870, 81033, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81033, 'Name': 'Macoma', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (178511, 176641, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 178511, 'Name': 'Lanius excubitor', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 176641, 'Name': 'Calidris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (178511, 179531, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 178511, 'Name': 'Lanius excubitor', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 179531, 'Name': 'Plectrophenax', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (178511, 113265, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 178511, 'Name': 'Lanius excubitor', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 113265, 'Name': 'Staphylinidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (72023, 48396, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 72023, 'Name': 'Cerithiopsis', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 48396, 'Name': 'Halichondria panicea', 'Phylum': 'Porifera', 'Intertidal': True, 'Nearshore': True}
# (176475, 69794, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 69794, 'Name': 'Trochidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 568350, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 568350, 'Name': 'Lottia persona', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 154883, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 154883, 'Name': 'Phascolosomatidae', 'Phylum': 'Sipuncula', 'Intertidal': True, 'Nearshore': True}
# (176475, 69662, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 69662, 'Name': 'Acmaea mitra', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 78979, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 78979, 'Name': 'Katharina tunicata', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 79452, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79452, 'Name': 'Mytilus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 157225, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157225, 'Name': 'Leptasterias', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (176475, 73293, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73293, 'Name': 'Nucella canaliculata', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 78897, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 78897, 'Name': 'Tonicella', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 48739, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 48739, 'Name': 'Hydrozoa', 'Phylum': 'Cnidaria', 'Intertidal': True, 'Nearshore': True}
# (176475, 567823, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 567823, 'Name': 'Lottia pelta', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 73294, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73294, 'Name': 'Nucella lamellosa', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 70395, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 70395, 'Name': 'Littorina', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 92564, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 92564, 'Name': 'Idoteidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (176475, 65870, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 65870, 'Name': 'Nereididae', 'Phylum': 'Annelida', 'Intertidal': True, 'Nearshore': True}
# (176475, 89609, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 89609, 'Name': 'Balanus glandula', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (176475, 81464, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81464, 'Name': 'Protothaca staminea', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (176475, 81446, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 176475, 'Name': 'Haematopus bachmani', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# ...
# (180092, 11289, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11289, 'Name': 'Alaria', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (180092, 98663, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98663, 'Name': 'Telmessus cheiragonus', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180092, 686683, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 686683, 'Name': 'Bubo scandiacus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 79791, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79791, 'Name': 'Pododesmus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 157969, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 157969, 'Name': 'Strongylocentrotus droebachiensis', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (180092, 180547, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 180547, 'Name': 'Enhydra lutris', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 12841, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 12841, 'Name': 'Palmaria', 'Phylum': 'Rhodophyta', 'Intertidal': True, 'Nearshore': True}
# (180092, 177019, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 177019, 'Name': 'Aethia cristatella', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 177032, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 177032, 'Name': 'Fratercula cirrhata', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 78979, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 78979, 'Name': 'Katharina tunicata', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 81033, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81033, 'Name': 'Macoma', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 80954, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 80954, 'Name': 'Tresus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 81464, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81464, 'Name': 'Protothaca staminea', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 175184, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 175184, 'Name': 'Mergus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 175160, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 175160, 'Name': 'Somateria spectabilis', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 11334, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 11334, 'Name': 'Fucus', 'Phylum': 'Phaeophyta', 'Intertidal': True, 'Nearshore': True}
# (180092, 170919, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 170919, 'Name': 'Trichodon trichodon', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 96746, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 96746, 'Name': 'Hippolytidae', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180092, 177029, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 177029, 'Name': 'Fratercula corniculata', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 159446, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 159446, 'Name': 'Pyura', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 81446, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81446, 'Name': 'Saxidomus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 175155, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 175155, 'Name': 'Somateria mollissima', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 81760, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81760, 'Name': 'Hiatellidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 162030, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 162030, 'Name': 'Hypomesus pretiosus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 180649, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 180649, 'Name': 'Phoca vitulina', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 656266, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 656266, 'Name': 'Balanus nubilus', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180092, 73294, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73294, 'Name': 'Nucella lamellosa', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 70395, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 70395, 'Name': 'Littorina', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 177013, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 177013, 'Name': 'Ptychoramphus aleuticus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 72878, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 72878, 'Name': 'Naticidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 73296, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73296, 'Name': 'Nucella lima', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 175042, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 175042, 'Name': 'Chen canagica', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 568350, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 568350, 'Name': 'Lottia persona', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 159300, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 159300, 'Name': 'Styela', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 174468, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 174468, 'Name': 'Gavia', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 79032, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79032, 'Name': 'Cryptochiton stelleri', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 176698, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 176698, 'Name': 'Gallinago', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 174725, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 174725, 'Name': 'Phalacrocorax pelagicus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 557227, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 557227, 'Name': 'Enteroctopus dofleini', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 177008, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 177008, 'Name': 'Synthliboramphus antiquus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 176808, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 176808, 'Name': 'Larus hyperboreus', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 79452, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79452, 'Name': 'Mytilus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 158191, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 158191, 'Name': 'Cucumaria', 'Phylum': 'Echinodermata', 'Intertidal': True, 'Nearshore': True}
# (180092, 175011, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 175011, 'Name': 'Branta bernicla', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 73293, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 73293, 'Name': 'Nucella canaliculata', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 52569, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 52569, 'Name': 'Urticina', 'Phylum': 'Cnidaria', 'Intertidal': True, 'Nearshore': True}
# (180092, 80866, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 80866, 'Name': 'Clinocardium', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 57443, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 57443, 'Name': 'Lineidae', 'Phylum': 'Nemertea', 'Intertidal': True, 'Nearshore': True}
# (180092, 176814, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 176814, 'Name': 'Larus glaucescens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 176614, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 176614, 'Name': 'Tringa melanoleuca', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 79500, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 79500, 'Name': 'Modiolus', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 89609, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 89609, 'Name': 'Balanus glandula', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180092, 1447, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 1447, 'Name': 'Chrysophyta', 'Phylum': 'Chrysophyta', 'Intertidal': True, 'Nearshore': True}
# (180092, 52562, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 52562, 'Name': 'Epiactis', 'Phylum': 'Cnidaria', 'Intertidal': True, 'Nearshore': True}
# (180092, 98671, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 98671, 'Name': 'Cancer', 'Phylum': 'Arthropoda', 'Intertidal': True, 'Nearshore': True}
# (180092, 52551, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 52551, 'Name': 'Anthopleura', 'Phylum': 'Cnidaria', 'Intertidal': True, 'Nearshore': True}
# (180092, 174513, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 174513, 'Name': 'Diomedeidae', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# (180092, 80982, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 80982, 'Name': 'Mactromeris', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 566908, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 566908, 'Name': 'Pharidae', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 81910, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 81910, 'Name': 'Entodesma', 'Phylum': 'Mollusca', 'Intertidal': True, 'Nearshore': True}
# (180092, 174999, {'Intertidal': True, 'Nearshore': True})
# {'TSN': 180092, 'Name': 'Homo sapiens', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# {'TSN': 174999, 'Name': 'Branta canadensis', 'Phylum': 'Chordata', 'Intertidal': True, 'Nearshore': True}
# 1546
# 0

# %%
#print all Phylum names ONCE 
phylum_names = set()
for node in G.nodes():
    phylum = G.nodes[node].get('Phylum', 'Unknown')
    phylum_names.add(phylum)
    #if the phylum is unknown or nan print it
for phylum in phylum_names:
    print(phylum)
# Out:
# Ascomycota
# Mollusca
# Haptophyta
# Bacillariophyta
# nan
# Phaeophyta
# Ectoprocta
# Cyanophycota
# Chaetognatha
# Arthropoda
# Nemertea
# Rhodophyta
# Acanthocephala
# Pyrrophycophyta
# Brachiopoda
# Chordata
# Chrysophyta
# Bacteria
# Ciliophora
# Phoronida
# Cnidaria
# Platyhelminthes
# Sarcomastigophora
# Porifera
# Magnoliophyta
# Nemata
# Annelida
# Sipuncula
# Echiura
# Prasinophyta
# Echinodermata
# Protozoa
# Chlorophyta

# %%
# Check for nodes with missing phylum information
print("Checking for nodes with missing phylum information:")
nan_phylum_nodes = []
for node in G.nodes():
    phylum = G.nodes[node].get('Phylum', 'Unknown')
    if pd.isna(phylum) or phylum == 'nan' or phylum == '':
        nan_phylum_nodes.append(node)

print(f"Found {len(nan_phylum_nodes)} nodes with missing phylum information:")
for i, node in enumerate(nan_phylum_nodes[:10]):  # Show first 10
    node_data = G.nodes[node]
    print(f"  {i+1}. TSN: {node_data.get('TSN', 'N/A')}, Name: {node_data.get('Name', 'N/A')}")

if len(nan_phylum_nodes) > 10:
    print(f"  ... and {len(nan_phylum_nodes) - 10} more nodes")

# Show statistics about phylum distribution
print(f"\nPhylum distribution in the network:")
phylum_counts = {}
for node in G.nodes():
    phylum = G.nodes[node].get('Phylum', 'Unknown')
    if pd.isna(phylum) or phylum == 'nan':
        phylum = 'Unknown/Missing'
    phylum_counts[phylum] = phylum_counts.get(phylum, 0) + 1

# Sort by count and show all phyla
sorted_phyla = sorted(phylum_counts.items(), key=lambda x: x[1], reverse=True)
for phylum, count in sorted_phyla:
    print(f"  {phylum}: {count} nodes")

# Show all nodes with 'nan' phylum in detail
if nan_phylum_nodes:
    print(f"\nDetailed view of all {len(nan_phylum_nodes)} nodes with missing phylum:")
    for i, node in enumerate(nan_phylum_nodes):
        node_data = G.nodes[node]
        print(f"  {i+1}. TSN: {node_data.get('TSN', 'N/A')}, Name: {node_data.get('Name', 'N/A')}, Phylum: {node_data.get('Phylum', 'N/A')}")
        print(f"      Intertidal: {node_data.get('Intertidal', 'N/A')}, Nearshore: {node_data.get('Nearshore', 'N/A')}")
        print(f"      In-degree: {G.in_degree(node)}, Out-degree: {G.out_degree(node)}")
        print()
# Out:
# Checking for nodes with missing phylum information:
# Found 2 nodes with missing phylum information:
#   1. TSN: san266, Name: Detritus complex
#   2. TSN: san272, Name: Biofilm Complex
#
# Phylum distribution in the network:
#   Chordata: 232 nodes
#   Mollusca: 67 nodes
#   Arthropoda: 63 nodes
#   Annelida: 26 nodes
#   Echinodermata: 23 nodes
#   Bacillariophyta: 15 nodes
#   Rhodophyta: 13 nodes
#   Phaeophyta: 12 nodes
#   Pyrrophycophyta: 9 nodes
#   Platyhelminthes: 9 nodes
#   Cnidaria: 9 nodes
#   Chlorophyta: 5 nodes
#   Nemertea: 4 nodes
#   Nemata: 4 nodes
#   Protozoa: 3 nodes
#   Porifera: 3 nodes
#   Unknown/Missing: 2 nodes
#   Sarcomastigophora: 2 nodes
#   Acanthocephala: 2 nodes
#   Ciliophora: 2 nodes
#   Prasinophyta: 2 nodes
#   Ascomycota: 2 nodes
#   Haptophyta: 1 nodes
#   Magnoliophyta: 1 nodes
#   Cyanophycota: 1 nodes
#   Chaetognatha: 1 nodes
#   Brachiopoda: 1 nodes
#   Sipuncula: 1 nodes
#   Echiura: 1 nodes
#   Chrysophyta: 1 nodes
#   Bacteria: 1 nodes
#   Phoronida: 1 nodes
#   Ectoprocta: 1 nodes
#
# Detailed view of all 2 nodes with missing phylum:
#   1. TSN: san266, Name: Detritus complex, Phylum: nan
#       Intertidal: False, Nearshore: True
#       In-degree: 176, Out-degree: 0
#
#   2. TSN: san272, Name: Biofilm Complex, Phylum: nan
#       Intertidal: False, Nearshore: True
#       In-degree: 22, Out-degree: 0

# %%
#now we want to make another graph where we group the nodes by their phylum and we make an edge between them if they are connected in the original graph

# Create a new graph where nodes represent phyla
phylum_graph = nx.DiGraph()

# Get all unique phyla from the original graph
phyla = set()
for node in G.nodes():
    phylum = G.nodes[node].get('Phylum', 'Unknown')
    phyla.add(phylum)

# Add phylum nodes to the new graph
for phylum in phyla:
    phylum_graph.add_node(phylum)

# Count connections between phyla
phylum_connections = {}
for edge in G.edges(data=True):
    source_node = edge[0]
    target_node = edge[1]
    
    source_phylum = G.nodes[source_node].get('Phylum', 'Unknown')
    target_phylum = G.nodes[target_node].get('Phylum', 'Unknown')
    
    # Create edge key for the phylum connection
    edge_key = (source_phylum, target_phylum)
    
    # Count the number of connections between these phyla
    if edge_key in phylum_connections:
        phylum_connections[edge_key] += 1
    else:
        phylum_connections[edge_key] = 1

# Add edges between phyla with weights representing connection counts
for (source_phylum, target_phylum), count in phylum_connections.items():
    if source_phylum != target_phylum:  # Don't add self-loops
        phylum_graph.add_edge(source_phylum, target_phylum, weight=count)

print(f"Phylum graph has {phylum_graph.number_of_nodes()} nodes and {phylum_graph.number_of_edges()} edges")

# Create hierarchical layout for the phylum-level network
plt.figure(figsize=(20, 12))

# Initialize levels dictionary - always define this outside try block
levels = {}

# Calculate hierarchical positions based on trophic levels
# Use networkx's topological sort to determine hierarchy
try:
    # Try to find a topological ordering
    topo_order = list(nx.topological_sort(phylum_graph))
    
    # If the graph has cycles, use strongly connected components
    if len(topo_order) != phylum_graph.number_of_nodes():
        scc = list(nx.strongly_connected_components(phylum_graph))
        # Flatten the strongly connected components
        topo_order = [node for component in scc for node in component]
    
    # Create hierarchical levels based on connectivity
    processed = set()
    
    # Assign levels based on in-degree (trophic level)
    for node in phylum_graph.nodes():
        in_degree = phylum_graph.in_degree(node)
        levels[node] = in_degree
    
    # Normalize levels to create distinct horizontal layers
    unique_levels = sorted(set(levels.values()))
    level_mapping = {level: i for i, level in enumerate(unique_levels)}
    
    # Create hierarchical positions
    pos = {}
    level_counts = {}
    
    for node in phylum_graph.nodes():
        level = level_mapping[levels[node]]
        if level not in level_counts:
            level_counts[level] = 0
        pos[node] = (level_counts[level], level)
        level_counts[level] += 1
    
    # Adjust spacing between levels
    for node in pos:
        pos[node] = (pos[node][0] * 3, pos[node][1] * 4)

except:
    # Fallback to spring layout if hierarchical layout fails
    pos = nx.spring_layout(phylum_graph, k=3, iterations=100)
    # Still assign levels based on in-degree for coloring
    for node in phylum_graph.nodes():
        in_degree = phylum_graph.in_degree(node)
        levels[node] = in_degree

# Draw nodes with colors based on hierarchical level
node_colors = []
for node in phylum_graph.nodes():
    level = levels.get(node, 0)
    # Use a colormap to assign colors based on trophic level
    color_value = level / max(levels.values()) if levels.values() else 0
    node_colors.append(color_value)

# Draw nodes
nx.draw_networkx_nodes(phylum_graph, pos, 
                      node_color=node_colors,
                      cmap=plt.cm.viridis,
                      node_size=1500,
                      alpha=0.8,
                      edgecolors='black',
                      linewidths=2)

# Draw edges with thickness proportional to weight
edges = phylum_graph.edges()
weights = [phylum_graph[u][v]['weight'] for u, v in edges]

# Normalize weights for visualization
if weights:
    max_weight = max(weights)
    min_weight = min(weights)
    if max_weight > min_weight:
        normalized_weights = [(w - min_weight) / (max_weight - min_weight) * 8 + 1 for w in weights]
    else:
        normalized_weights = [3] * len(weights)
else:
    normalized_weights = [3]

# Color edges based on direction (hierarchical flow)
edge_colors = []
for u, v in edges:
    u_level = levels.get(u, 0)
    v_level = levels.get(v, 0)
    if u_level < v_level:  # Going up the hierarchy
        edge_colors.append('red')
    elif u_level > v_level:  # Going down the hierarchy
        edge_colors.append('blue')
    else:  # Same level
        edge_colors.append('gray')

nx.draw_networkx_edges(phylum_graph, pos,
                      width=normalized_weights,
                      alpha=0.7,
                      edge_color=edge_colors,
                      arrows=True,
                      arrowsize=25,
                      arrowstyle='->')

# Add labels with better positioning
label_pos = {}
for node, (x, y) in pos.items():
    label_pos[node] = (x, y - 0.3)  # Offset labels below nodes

nx.draw_networkx_labels(phylum_graph, label_pos,
                       font_size=10,
                       font_weight='bold',
                       bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8))

# Add colorbar for trophic levels
sm = plt.cm.ScalarMappable(cmap=plt.cm.viridis, norm=plt.Normalize(vmin=0, vmax=max(levels.values())))
sm.set_array([])
cbar = plt.colorbar(sm, ax=plt.gca(), shrink=0.8)
cbar.set_label('Trophic Level (In-degree)', rotation=270, labelpad=20)

# Add legend for edge colors
from matplotlib.patches import Patch
legend_elements = [Patch(facecolor='red', label='Upward flow (lower → higher trophic level)'),
                  Patch(facecolor='blue', label='Downward flow (higher → lower trophic level)'),
                  Patch(facecolor='gray', label='Same trophic level')]
plt.legend(handles=legend_elements, loc='upper right', bbox_to_anchor=(1.15, 1))

plt.title('Hierarchical Phylum-Level Food Web Network\n(Edge thickness = connection strength, Colors = trophic flow direction)', 
          fontsize=14, pad=20)
plt.axis('off')
plt.tight_layout()
plt.show()

# Print some statistics about phylum connections
print("\nTop 10 phylum connections (by number of edges):")
sorted_connections = sorted(phylum_connections.items(), key=lambda x: x[1], reverse=True)
for i, ((source, target), count) in enumerate(sorted_connections[:10]):
    print(f"{i+1}. {source} -> {target}: {count} connections")
# Out:
# Phylum graph has 33 nodes and 190 edges
# Top 10 phylum connections (by number of edges):
# 1. Chordata -> Chordata: 1715 connections
# 2. Chordata -> Arthropoda: 1559 connections
# 3. Chordata -> Mollusca: 540 connections
# 4. Chordata -> Annelida: 400 connections
# 5. Arthropoda -> Bacillariophyta: 134 connections
# 6. Echinodermata -> Mollusca: 121 connections
# 7. Arthropoda -> Arthropoda: 114 connections
# 8. Chordata -> Echinodermata: 107 connections
# 9. Nemata -> Chordata: 84 connections
# 10. Arthropoda -> Mollusca: 83 connections

# %%
# Import required libraries for link prediction
from sklearn.metrics import roc_curve, roc_auc_score
import random

# Define similarity functions for directed graphs

def directed_jaccard_coefficient(G, u, v):
    """Compute a symmetric Jaccard coefficient using both in- and out-neighbors."""
    neigh_u = set(G.successors(u)) | set(G.predecessors(u))
    neigh_v = set(G.successors(v)) | set(G.predecessors(v))
    if not neigh_u or not neigh_v:
        return 0.0
    return len(neigh_u & neigh_v) / len(neigh_u | neigh_v)


def directed_preferential_attachment(G, u, v):
    """Directed preferential attachment = outdegree(u) * indegree(v)."""
    return G.out_degree(u) * G.in_degree(v)


# Leave-one-out prediction functions

def getPredictionsLeaveOneOutDirectedJaccard(G, n_neg=20):
    """
    Leave-one-out link prediction using directed Jaccard.
    For each removed edge, compute similarity for that edge (positive)
    and n_neg random non-edges (negatives).
    """
    probs, labels = [], []
    nodes = list(G.nodes())
    all_possible_pairs = [(a, b) for a in nodes for b in nodes if a != b]

    for e in list(G.edges()):
        u, v = e
        Gprobed = G.copy()
        Gprobed.remove_edge(u, v)

        p_pos = directed_jaccard_coefficient(Gprobed, u, v)
        probs.append(p_pos)
        labels.append(1)

        non_edges = [(a, b) for (a, b) in all_possible_pairs if not Gprobed.has_edge(a, b)]

        if not non_edges:
            continue  

        sampled_non_edges = random.sample(non_edges, min(n_neg, len(non_edges)))
        for (a, b) in sampled_non_edges:
            p_neg = directed_jaccard_coefficient(Gprobed, a, b)
            probs.append(p_neg)
            labels.append(0)

    return probs, labels


def getPredictionsLeaveOneOutDirectedPA(G, n_neg=20):
    """
    Leave-one-out link prediction using directed preferential attachment.
    For each removed edge, compute the score for that edge (positive)
    and n_neg random non-edges (negatives).
    """
    probs, labels = [], []
    nodes = list(G.nodes())

    for e in list(G.edges()):
        u, v = e
        Gprobed = G.copy()
        Gprobed.remove_edge(u, v)

        p_pos = directed_preferential_attachment(Gprobed, u, v)
        probs.append(p_pos)
        labels.append(1)

        non_edges = set()
        while len(non_edges) < n_neg:
            a, b = random.sample(nodes, 2)
            if not Gprobed.has_edge(a, b):
                non_edges.add((a, b))

        for (a, b) in non_edges:
            p_neg = directed_preferential_attachment(Gprobed, a, b)
            probs.append(p_neg)
            labels.append(0)

    return probs, labels


# Leave-k-out prediction functions

def getPredictionsLeaveKOutDirectedJaccard(G, k=5, n_neg=5):
    """
    Iterates over the entire graph, removing k edges at a time.
    For each batch:
      - compute directed Jaccard for the k removed edges (positives)
      - sample n_neg * k random non-edges as negatives.
    Returns full lists of probs and labels for all batches.
    """
    probs, labels = [], []
    edges = list(G.edges())
    nodes = list(G.nodes())
    all_pairs = [(a, b) for a in nodes for b in nodes if a != b]

    random.shuffle(edges)
    batches = [edges[i:i+k] for i in range(0, len(edges), k)]

    for batch_edges in batches:
        Gprobed = G.copy()
        Gprobed.remove_edges_from(batch_edges)

        for (u, v) in batch_edges:
            p = directed_jaccard_coefficient(Gprobed, u, v)
            probs.append(p)
            labels.append(1)

        non_edges = [(a, b) for (a, b) in all_pairs if not Gprobed.has_edge(a, b)]
        if len(non_edges) == 0:
            continue
        n_neg_total = min(len(non_edges), n_neg * len(batch_edges))
        sampled_neg = random.sample(non_edges, n_neg_total)

        for (a, b) in sampled_neg:
            p = directed_jaccard_coefficient(Gprobed, a, b)
            probs.append(p)
            labels.append(0)

    return probs, labels


def getPredictionsLeaveKOutDirectedPA(G, k=5, n_neg=5):
    """
    Leave-k-out link prediction using directed preferential attachment.
    """
    probs, labels = [], []
    edges = list(G.edges())
    nodes = list(G.nodes())
    all_pairs = [(a, b) for a in nodes for b in nodes if a != b]

    random.shuffle(edges)
    batches = [edges[i:i+k] for i in range(0, len(edges), k)]

    for batch_edges in batches:
        Gprobed = G.copy()
        Gprobed.remove_edges_from(batch_edges)

        for (u, v) in batch_edges:
            p = directed_preferential_attachment(Gprobed, u, v)
            probs.append(p)
            labels.append(1)

        non_edges = [(a, b) for (a, b) in all_pairs if not Gprobed.has_edge(a, b)]
        if len(non_edges) == 0:
            continue
        n_neg_total = min(len(non_edges), n_neg * len(batch_edges))
        sampled_neg = random.sample(non_edges, n_neg_total)

        for (a, b) in sampled_neg:
            p = directed_preferential_attachment(Gprobed, a, b)
            probs.append(p)
            labels.append(0)

    return probs, labels

print("Link prediction functions defined successfully!")
# Out:
# Link prediction functions defined successfully!

# %%
def build_phylum_graph(G):
    """
    Build a phylum graph from the species-level graph G.
    Returns a directed graph where nodes are phyla and edge weights represent
    the number of connections between species of those phyla.
    """
    phylum_g = nx.DiGraph()
    
    # Get all unique phyla from G
    phyla = set()
    for node in G.nodes():
        phylum = G.nodes[node].get('Phylum', 'Unknown')
        if pd.isna(phylum):
            phylum = 'Unknown'
        phyla.add(phylum)
    
    # Add phylum nodes
    for phylum in phyla:
        phylum_g.add_node(phylum)
    
    # Count connections between phyla
    phylum_connections = {}
    for u, v in G.edges():
        source_phylum = G.nodes[u].get('Phylum', 'Unknown')
        target_phylum = G.nodes[v].get('Phylum', 'Unknown')
        
        if pd.isna(source_phylum):
            source_phylum = 'Unknown'
        if pd.isna(target_phylum):
            target_phylum = 'Unknown'
        
        edge_key = (source_phylum, target_phylum)
        phylum_connections[edge_key] = phylum_connections.get(edge_key, 0) + 1
    
    # Add edges between phyla with weights
    for (source_phylum, target_phylum), count in phylum_connections.items():
        phylum_g.add_edge(source_phylum, target_phylum, weight=count)
    
    return phylum_g


def eco_trophic_similarity(G, u, v, phylum_g=None):
    """
    Custom similarity for predator-prey networks.
    Combines trophic role, phylum affinity, and degree complementarity.
    
    Parameters:
    - G: The species-level graph
    - u, v: Nodes to compute similarity for
    - phylum_g: Optional phylum graph (if None, uses global phylum_graph)
    """
    # Use uppercase "Phylum" to match the actual attribute in G
    phylum_u = G.nodes[u].get("Phylum", "Unknown")
    phylum_v = G.nodes[v].get("Phylum", "Unknown")
    
    # Handle NaN values
    if pd.isna(phylum_u):
        phylum_u = "Unknown"
    if pd.isna(phylum_v):
        phylum_v = "Unknown"

    indeg_u, outdeg_u = G.in_degree(u), G.out_degree(u)
    indeg_v, outdeg_v = G.in_degree(v), G.out_degree(v)

    denom_u = max(indeg_u + outdeg_u, 1)
    denom_v = max(indeg_v + outdeg_v, 1)

    trophic_score = (outdeg_u / denom_u) * (indeg_v / denom_v)

    # Phylum affinity score using the phylum graph
    phylum_score = 0
    if phylum_g is not None:
        try:
            # Normalize by max weight in phylum graph to get score between 0 and 1
            weight = phylum_g[phylum_u][phylum_v].get('weight', 0)
            max_weight = max([phylum_g[s][t].get('weight', 0) 
                            for s, t in phylum_g.edges()], default=1)
            phylum_score = weight / max(max_weight, 1)
        except (KeyError, ValueError):
            phylum_score = 0
    elif 'phylum_graph' in globals():
        try:
            weight = phylum_graph[phylum_u][phylum_v].get('weight', 0)
            max_weight = max([phylum_graph[s][t].get('weight', 0) 
                            for s, t in phylum_graph.edges()], default=1)
            phylum_score = weight / max(max_weight, 1)
        except (KeyError, ValueError):
            phylum_score = 0

    comp_score = (outdeg_u - indeg_v + 1) / (outdeg_u + indeg_v + 1)

    score = 0.5 * trophic_score + 0.3 * phylum_score + 0.2 * comp_score
    return score

# %% [markdown]
# ### Important Note on Phylum Graph and Information Leakage
#
# The `eco_trophic_similarity` function now properly handles the phylum graph to avoid information leakage:
#
# 1. **build_phylum_graph(G)**: Creates a phylum-level graph from the species graph G, where:
#    - Nodes are phyla
#    - Edge weights represent the number of connections between species of those phyla
#
# 2. **Phylum attribute fix**: Changed from `"phylum"` (lowercase) to `"Phylum"` (uppercase) to match the actual node attributes in the graph.
#
# 3. **Dynamic phylum graph updates**:
#    - In **leave-one-out**: The phylum graph is rebuilt for each test edge after removing that edge from the species graph
#    - In **k-fold**: The phylum graph is rebuilt for each fold using only the training edges
#
# This ensures that test edge information doesn't leak into the phylum affinity scores used for prediction.

# %%
# Test the build_phylum_graph function
print("Testing build_phylum_graph function...")
test_phylum_graph = build_phylum_graph(G)
print(f"Phylum graph: {test_phylum_graph.number_of_nodes()} nodes, {test_phylum_graph.number_of_edges()} edges")
print("\nSample phylum edges with weights:")
sample_edges = list(test_phylum_graph.edges(data=True))[:5]
for u, v, data in sample_edges:
    print(f"  {u} -> {v}: weight={data.get('weight', 0)}")

# Test eco_trophic_similarity with the phylum graph
print("\n\nTesting eco_trophic_similarity...")
# Pick two nodes from G
test_nodes = list(G.nodes())[:2]
if len(test_nodes) >= 2:
    u, v = test_nodes[0], test_nodes[1]
    sim_score = eco_trophic_similarity(G, u, v, phylum_g=test_phylum_graph)
    print(f"Similarity score between nodes {u} and {v}: {sim_score:.4f}")
    print(f"  Node {u}: Phylum = {G.nodes[u].get('Phylum', 'Unknown')}")
    print(f"  Node {v}: Phylum = {G.nodes[v].get('Phylum', 'Unknown')}")
else:
    print("Not enough nodes to test similarity")

print("\nFunctions work correctly!")
# Out:
# Testing build_phylum_graph function...
# Phylum graph: 33 nodes, 201 edges
#
# Sample phylum edges with weights:
#   Mollusca -> Unknown: weight=50
#   Mollusca -> Rhodophyta: weight=49
#   Mollusca -> Phaeophyta: weight=39
#   Mollusca -> Chlorophyta: weight=22
#   Mollusca -> Chordata: weight=20
#
#
# Testing eco_trophic_similarity...
# Similarity score between nodes 86038 and 69662: 0.2398
#   Node 86038: Phylum = Arthropoda
#   Node 69662: Phylum = Mollusca
#
# Functions work correctly!

# %%
# K-Fold Cross-Validation Implementation

def getPredictionsKFold(G, n_folds=5, n_neg=10, similarity_func=directed_jaccard_coefficient):
    """
    K-fold cross-validation for link prediction.
    Splits edges into n_folds, uses each fold as test set once.
    
    Parameters:
    - G: NetworkX DiGraph
    - n_folds: number of folds
    - n_neg: number of negative samples per positive edge
    - similarity_func: function to compute similarity between nodes
    
    Returns:
    - probs: list of predicted probabilities/scores
    - labels: list of true labels (1 for real edges, 0 for non-edges)
    """
    probs, labels = [], []
    edges = list(G.edges())
    nodes = list(G.nodes())
    
    # Shuffle edges for random splits
    random.shuffle(edges)
    
    # Split edges into folds
    fold_size = len(edges) // n_folds
    folds = [edges[i*fold_size:(i+1)*fold_size] for i in range(n_folds)]
    # Add remaining edges to last fold
    if len(edges) % n_folds != 0:
        folds[-1].extend(edges[n_folds*fold_size:])
    
    print(f"Running {n_folds}-fold cross-validation...")
    print(f"Total edges: {len(edges)}, Fold sizes: {[len(f) for f in folds]}")
    
    for fold_idx, test_edges in enumerate(folds):
        print(f"  Processing fold {fold_idx + 1}/{n_folds}...", end=" ")
        
        # Create training graph (remove test edges)
        G_train = G.copy()
        G_train.remove_edges_from(test_edges)
        
        # Evaluate on test edges (positives)
        for u, v in test_edges:
            if G_train.has_node(u) and G_train.has_node(v):
                score = similarity_func(G_train, u, v)
                probs.append(score)
                labels.append(1)
        
        # Sample negative edges
        all_possible_pairs = [(a, b) for a in nodes for b in nodes if a != b]
        non_edges = [(a, b) for (a, b) in all_possible_pairs if not G.has_edge(a, b)]
        
        if non_edges:
            n_neg_total = min(len(non_edges), n_neg * len(test_edges))
            sampled_non_edges = random.sample(non_edges, n_neg_total)
            
            for a, b in sampled_non_edges:
                if G_train.has_node(a) and G_train.has_node(b):
                    score = similarity_func(G_train, a, b)
                    probs.append(score)
                    labels.append(0)
        
        print(f"Done ({len(test_edges)} pos, {n_neg_total if non_edges else 0} neg)")
    
    return probs, labels


def getPredictionsKFoldPA(G, n_folds=5, n_neg=10):
    """K-fold cross-validation using Preferential Attachment."""
    probs, labels = [], []
    edges = list(G.edges())
    nodes = list(G.nodes())
    
    random.shuffle(edges)
    fold_size = len(edges) // n_folds
    folds = [edges[i*fold_size:(i+1)*fold_size] for i in range(n_folds)]
    if len(edges) % n_folds != 0:
        folds[-1].extend(edges[n_folds*fold_size:])
    
    print(f"Running {n_folds}-fold cross-validation (Preferential Attachment)...")
    
    for fold_idx, test_edges in enumerate(folds):
        print(f"  Processing fold {fold_idx + 1}/{n_folds}...", end=" ")
        
        G_train = G.copy()
        G_train.remove_edges_from(test_edges)
        
        for u, v in test_edges:
            if G_train.has_node(u) and G_train.has_node(v):
                score = directed_preferential_attachment(G_train, u, v)
                probs.append(score)
                labels.append(1)
        
        non_edges = set()
        attempts = 0
        max_attempts = n_neg * len(test_edges) * 10
        while len(non_edges) < n_neg * len(test_edges) and attempts < max_attempts:
            a, b = random.choice(nodes), random.choice(nodes)
            if a != b and not G.has_edge(a, b):
                non_edges.add((a, b))
            attempts += 1
        
        for a, b in non_edges:
            if G_train.has_node(a) and G_train.has_node(b):
                score = directed_preferential_attachment(G_train, a, b)
                probs.append(score)
                labels.append(0)
        
        print(f"Done ({len(test_edges)} pos, {len(non_edges)} neg)")
    
    return probs, labels


def getPredictionsKFoldEcoTrophic(G, n_folds=5, n_neg=10):
    """
    K-fold cross-validation using eco_trophic_similarity.
    
    IMPORTANT: This function rebuilds the phylum_graph for each fold
    using only the training data to avoid information leakage.
    """
    probs, labels = [], []
    edges = list(G.edges())
    nodes = list(G.nodes())
    
    random.shuffle(edges)
    fold_size = len(edges) // n_folds
    folds = [edges[i*fold_size:(i+1)*fold_size] for i in range(n_folds)]
    if len(edges) % n_folds != 0:
        folds[-1].extend(edges[n_folds*fold_size:])
    
    print(f"Running {n_folds}-fold cross-validation (Eco-Trophic Similarity)...")
    
    for fold_idx, test_edges in enumerate(folds):
        print(f"  Processing fold {fold_idx + 1}/{n_folds}...", end=" ")
        
        # Create training graph (remove test edges)
        G_train = G.copy()
        G_train.remove_edges_from(test_edges)
        
        # Build phylum graph from training data only
        phylum_g_train = build_phylum_graph(G_train)
        
        # Evaluate on test edges (positives)
        for u, v in test_edges:
            if G_train.has_node(u) and G_train.has_node(v):
                score = eco_trophic_similarity(G_train, u, v, phylum_g=phylum_g_train)
                probs.append(score)
                labels.append(1)
        
        # Sample negative edges
        non_edges = set()
        attempts = 0
        max_attempts = n_neg * len(test_edges) * 10
        while len(non_edges) < n_neg * len(test_edges) and attempts < max_attempts:
            a, b = random.choice(nodes), random.choice(nodes)
            if a != b and not G.has_edge(a, b):
                non_edges.add((a, b))
            attempts += 1
        
        # Evaluate on negative edges
        for a, b in non_edges:
            if G_train.has_node(a) and G_train.has_node(b):
                score = eco_trophic_similarity(G_train, a, b, phylum_g=phylum_g_train)
                probs.append(score)
                labels.append(0)
        
        print(f"Done ({len(test_edges)} pos, {len(non_edges)} neg)")
    
    return probs, labels


print("K-Fold cross-validation functions defined successfully!")
# Out:
# K-Fold cross-validation functions defined successfully!

# %%
# Define Leave-One-Out with Custom Similarity Function (eco_trophic_similarity)

def getPredictionsLeaveOneOutEcoTrophic(G, n_neg=20):
    """
    Leave-one-out link prediction using eco_trophic_similarity.
    For each removed edge, compute similarity for that edge (positive)
    and n_neg random non-edges (negatives).
    
    IMPORTANT: This function rebuilds the phylum_graph for each test edge
    to avoid information leakage.
    """
    probs, labels = [], []
    nodes = list(G.nodes())
    all_possible_pairs = [(a, b) for a in nodes for b in nodes if a != b]

    for e in list(G.edges()):
        u, v = e
        # Remove the test edge
        Gprobed = G.copy()
        Gprobed.remove_edge(u, v)
        
        # Rebuild phylum graph based on the probed graph (without the test edge)
        phylum_g_probed = build_phylum_graph(Gprobed)

        # Compute similarity for the positive (removed) edge
        p_pos = eco_trophic_similarity(Gprobed, u, v, phylum_g=phylum_g_probed)
        probs.append(p_pos)
        labels.append(1)

        # Sample negative edges
        non_edges = [(a, b) for (a, b) in all_possible_pairs if not Gprobed.has_edge(a, b)]

        if not non_edges:
            continue  

        sampled_non_edges = random.sample(non_edges, min(n_neg, len(non_edges)))
        for (a, b) in sampled_non_edges:
            p_neg = eco_trophic_similarity(Gprobed, a, b, phylum_g=phylum_g_probed)
            probs.append(p_neg)
            labels.append(0)

    return probs, labels


print("Leave-one-out with eco_trophic_similarity function defined!")
# Out:
# Leave-one-out with eco_trophic_similarity function defined!

# %%
# Leave-One-Out Link Prediction with Custom Similarity on Species-Level Graphs

# %%
# Link prediction on the full species-level graph with eco-trophic similarity (G)
print("Running link prediction on full species-level graph with eco-trophic similarity...")
print(f"Full graph G: {G.number_of_nodes()} nodes, {G.number_of_edges()} edges")
print("Note: This may take a while due to the large graph size...")

probs_j_full, labels_j_full = getPredictionsLeaveOneOutDirectedJaccard(G, n_neg=10)
probs_pa_full, labels_pa_full = getPredictionsLeaveOneOutDirectedPA(G, n_neg=10)
probs_custom_full, labels_custom_full = getPredictionsLeaveOneOutEcoTrophic(G, n_neg=10)

fpr_j_full, tpr_j_full, _ = roc_curve(labels_j_full, probs_j_full)
fpr_pa_full, tpr_pa_full, _ = roc_curve(labels_pa_full, probs_pa_full)
fpr_custom_full, tpr_custom_full, _ = roc_curve(labels_custom_full, probs_custom_full)

auc_j_full = roc_auc_score(labels_j_full, probs_j_full)
auc_pa_full = roc_auc_score(labels_pa_full, probs_pa_full)
auc_custom_full = roc_auc_score(labels_custom_full, probs_custom_full)

plt.figure(figsize=(8, 8))
plt.plot(fpr_j_full, tpr_j_full, "-.", label=f"Directed Jaccard (AUC={auc_j_full:.3f})", color="purple", linewidth=2)
plt.plot(fpr_pa_full, tpr_pa_full, "-", label=f"Directed Pref. Attach. (AUC={auc_pa_full:.3f})", color="orange", linewidth=2)
plt.plot(fpr_custom_full, tpr_custom_full, "--", label=f"Eco-Trophic Similarity (AUC={auc_custom_full:.3f})", color="green", linewidth=2)
plt.plot([0, 1], [0, 1], "--k", label="Random chance")

plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.title("ROC Curves for Link Prediction (Leave-One-Out)\nFull Species-Level Food Web", fontsize=14)
plt.legend(fontsize=11)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"AUC (Directed Jaccard): {auc_j_full:.4f}")
print(f"AUC (Directed Preferential Attachment): {auc_pa_full:.4f}")
print(f"AUC (Eco-Trophic Similarity): {auc_custom_full:.4f}")
# Out:
# Running link prediction on full species-level graph with eco-trophic similarity...
# Full graph G: 520 nodes, 6917 edges
# Note: This may take a while due to the large graph size...
# AUC (Directed Jaccard): 0.7411
# AUC (Directed Preferential Attachment): 0.8727
# AUC (Eco-Trophic Similarity): 0.6876

# %%
# Link prediction on intertidal subgraph with eco-trophic similarity
print("Running link prediction on intertidal subgraph with eco-trophic similarity...")
print(f"Intertidal graph: {intertidal_G.number_of_nodes()} nodes, {intertidal_G.number_of_edges()} edges")

probs_j_int, labels_j_int = getPredictionsLeaveOneOutDirectedJaccard(intertidal_G, n_neg=10)
probs_pa_int, labels_pa_int = getPredictionsLeaveOneOutDirectedPA(intertidal_G, n_neg=10)
probs_custom_int, labels_custom_int = getPredictionsLeaveOneOutEcoTrophic(intertidal_G, n_neg=10)

fpr_j_int, tpr_j_int, _ = roc_curve(labels_j_int, probs_j_int)
fpr_pa_int, tpr_pa_int, _ = roc_curve(labels_pa_int, probs_pa_int)
fpr_custom_int, tpr_custom_int, _ = roc_curve(labels_custom_int, probs_custom_int)

auc_j_int = roc_auc_score(labels_j_int, probs_j_int)
auc_pa_int = roc_auc_score(labels_pa_int, probs_pa_int)
auc_custom_int = roc_auc_score(labels_custom_int, probs_custom_int)

plt.figure(figsize=(8, 8))
plt.plot(fpr_j_int, tpr_j_int, "-.", label=f"Directed Jaccard (AUC={auc_j_int:.3f})", color="purple", linewidth=2)
plt.plot(fpr_pa_int, tpr_pa_int, "-", label=f"Directed Pref. Attach. (AUC={auc_pa_int:.3f})", color="orange", linewidth=2)
plt.plot(fpr_custom_int, tpr_custom_int, "--", label=f"Eco-Trophic Similarity (AUC={auc_custom_int:.3f})", color="green", linewidth=2)
plt.plot([0, 1], [0, 1], "--k", label="Random chance")

plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.title("ROC Curves for Link Prediction (Leave-One-Out)\nIntertidal Food Web", fontsize=14)
plt.legend(fontsize=11)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"AUC (Directed Jaccard): {auc_j_int:.4f}")
print(f"AUC (Directed Preferential Attachment): {auc_pa_int:.4f}")
print(f"AUC (Eco-Trophic Similarity): {auc_custom_int:.4f}")
# Out:
# Running link prediction on intertidal subgraph with eco-trophic similarity...
# Intertidal graph: 231 nodes, 1689 edges
# AUC (Directed Jaccard): 0.6617
# AUC (Directed Preferential Attachment): 0.8541
# AUC (Eco-Trophic Similarity): 0.7053

# %%
# Link prediction on nearshore subgraph with eco-trophic similarity
print("Running link prediction on nearshore subgraph with eco-trophic similarity...")
print(f"Nearshore graph: {nearshore_G.number_of_nodes()} nodes, {nearshore_G.number_of_edges()} edges")

probs_j_near, labels_j_near = getPredictionsLeaveOneOutDirectedJaccard(nearshore_G, n_neg=10)
probs_pa_near, labels_pa_near = getPredictionsLeaveOneOutDirectedPA(nearshore_G, n_neg=10)
probs_custom_near, labels_custom_near = getPredictionsLeaveOneOutEcoTrophic(nearshore_G, n_neg=10)

fpr_j_near, tpr_j_near, _ = roc_curve(labels_j_near, probs_j_near)
fpr_pa_near, tpr_pa_near, _ = roc_curve(labels_pa_near, probs_pa_near)
fpr_custom_near, tpr_custom_near, _ = roc_curve(labels_custom_near, probs_custom_near)

auc_j_near = roc_auc_score(labels_j_near, probs_j_near)
auc_pa_near = roc_auc_score(labels_pa_near, probs_pa_near)
auc_custom_near = roc_auc_score(labels_custom_near, probs_custom_near)

plt.figure(figsize=(8, 8))
plt.plot(fpr_j_near, tpr_j_near, "-.", label=f"Directed Jaccard (AUC={auc_j_near:.3f})", color="purple", linewidth=2)
plt.plot(fpr_pa_near, tpr_pa_near, "-", label=f"Directed Pref. Attach. (AUC={auc_pa_near:.3f})", color="orange", linewidth=2)
plt.plot(fpr_custom_near, tpr_custom_near, "--", label=f"Eco-Trophic Similarity (AUC={auc_custom_near:.3f})", color="green", linewidth=2)
plt.plot([0, 1], [0, 1], "--k", label="Random chance")

plt.xlabel("False Positive Rate", fontsize=12)
plt.ylabel("True Positive Rate", fontsize=12)
plt.title("ROC Curves for Link Prediction (Leave-One-Out)\nNearshore Food Web", fontsize=14)
plt.legend(fontsize=11)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

print(f"AUC (Directed Jaccard): {auc_j_near:.4f}")
print(f"AUC (Directed Preferential Attachment): {auc_pa_near:.4f}")
print(f"AUC (Eco-Trophic Similarity): {auc_custom_near:.4f}")
# Out:
# Running link prediction on nearshore subgraph with eco-trophic similarity...
# Nearshore graph: 513 nodes, 6774 edges
# AUC (Directed Jaccard): 0.7413
# AUC (Directed Preferential Attachment): 0.8734
# AUC (Eco-Trophic Similarity): 0.6914
